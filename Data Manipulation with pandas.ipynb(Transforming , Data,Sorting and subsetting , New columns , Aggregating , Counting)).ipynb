# %% [markdown]
# # Data Manipulation with pandas

# %% [markdown]
# # Transforming Data

# %%
import pandas as pd

# %%
# IMPORT CSV DATA
shopping_trends=pd.read_csv(r'C:\Users\User\Desktop\Dataset\shopping_trends.csv')
shopping_trends
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# Head returns the first rows (the "heading" of the DataFrame).
shopping_trends.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
# Shows the column names
# the types of data they contain and whether they have any missing values
shopping_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
# Tuple -- # rows, columns
shopping_trends.shape
# Out:
# (3900, 19)

# %%
# Calculate some characteristics for numerical columns
shopping_trends.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
# Parts of a DataFrame

print(shopping_trends.columns) #columns
print("--")

print(shopping_trends.index) #index
print("--")

# print(shopping_trends.values) # values
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')
# --
# RangeIndex(start=0, stop=3900, step=1)
# --

# %% [markdown]
# # Sorting and subsetting

# %%
shopping_trends.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
# df.sort_values("name_column") # Lowest to highest
# Lowest to highest
shopping_trends.sort_values("Purchase Amount (USD)").head()
# Highest to lowest
shopping_trends.sort_values("Purchase Amount (USD)",ascending = False).head()
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 2842         2843   28  Female           Coat  Outerwear
# 95             96   37    Male       Sneakers   Footwear
# 581           582   32    Male        Sweater   Clothing
# 1421         1422   68    Male          Dress   Clothing
# 3837         3838   45  Female         Hoodie   Clothing
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 2842                    100       Arizona    L     Green    Fall
# 95                      100      Missouri    L      Pink    Fall
# 581                     100          Iowa   XL  Charcoal  Winter
# 1421                    100  Pennsylvania    S      Gold  Spring
# 3837                    100    New Mexico    M     Green  Spring
#
#       Review Rating Subscription Status Payment Method  Shipping Type  \
# 2842            4.3                  No           Cash       Standard
# 95              3.8                 Yes         PayPal  Free Shipping
# ...

# %%
shopping_trends.sort_values(["Season","Category"],ascending=[False,True]).head()
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 30           31   57   Male        Jewelry  Accessories
# 40           41   69   Male        Handbag  Accessories
# 47           48   55   Male        Jewelry  Accessories
# 61           62   55   Male          Scarf  Accessories
# 63           64   33   Male     Sunglasses  Accessories
#
#     Purchase Amount (USD)        Location Size     Color  Season  \
# 30                     31  North Carolina    L     Black  Winter
# 40                     76       Louisiana    L     Beige  Winter
# 47                     54         Montana    M  Charcoal  Winter
# 61                     68           Texas    M    Orange  Winter
# 63                     79         Arizona    L  Lavender  Winter
#
#     Review Rating Subscription Status Payment Method   Shipping Type  \
# 30            4.7                 Yes  Bank Transfer        Standard
# 40            4.6                 Yes         PayPal    Next Day Air
# ...

# %%
# Select multiple columns
shopping_trends[["Age","Payment Method"]].head()
# Out:
#    Age Payment Method
# 0   55    Credit Card
# 1   19  Bank Transfer
# 2   50           Cash
# 3   21         PayPal
# 4   45           Cash

# %%
# subsets with conditionals
shopping_trends[shopping_trends["Age"]<32]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2652         2653   23  Female         Shorts     Clothing
# 2653         2654   67  Female         Blouse     Clothing
# 2654         2655   23  Female           Coat    Outerwear
# 2655         2656   26  Female     Sunglasses  Accessories
# 2656         2657   52  Female         Shorts     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 2652                     20    Maryland    L       Cyan  Summer
# 2653                     36   Wisconsin    L   Lavender    Fall
# ...

# %%
shopping_trends[shopping_trends["Location"] == "Hawaii"]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 11             12   30    Male         Shorts     Clothing
# 73             74   48    Male          Pants     Clothing
# 173           174   25    Male            Hat  Accessories
# 184           185   32    Male       Sneakers     Footwear
# 205           206   67    Male          Shirt     Clothing
# ...           ...  ...     ...            ...          ...
# 3285         3286   58  Female            Hat  Accessories
# 3482         3483   66  Female         Gloves  Accessories
# 3504         3505   65  Female        Handbag  Accessories
# 3710         3711   60  Female        Jewelry  Accessories
# 3825         3826   49  Female         Shorts     Clothing
#
#       Purchase Amount (USD) Location Size      Color  Season  Review Rating  \
# 11                       68   Hawaii    S      Olive  Winter            4.9
# 73                       85   Hawaii    M       Teal  Spring            2.7
# ...

# %%
# Sort shopping_trends by location,
# then descending Payment Method
shopping_trends_loc_pay=shopping_trends.sort_values(["Location","Payment Method"],ascending=[True,False])

display(shopping_trends_loc_pay.head())
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 16             17   25   Male     Sunglasses  Accessories
# 182           183   38   Male         Gloves  Accessories
# 258           259   61   Male         Gloves  Accessories
# 948           949   49   Male            Hat  Accessories
# 1500         1501   63   Male          Jeans     Clothing
#
#       Purchase Amount (USD) Location Size     Color  Season  Review Rating  \
# 16                       36  Alabama    S      Gray  Spring            4.1
# 182                      96  Alabama   XL    Purple  Summer            2.8
# 258                      74  Alabama    S  Lavender  Spring            2.8
# 948                      90  Alabama    L     Olive  Summer            4.9
# 1500                     69  Alabama    L    Maroon  Summer            4.8
#
#      Subscription Status Payment Method Shipping Type Discount Applied  \
# 16                   Yes          Venmo  Next Day Air              Yes
# ...

# %%
# Multiple conditionals

#is_item=shopping_trends["Item Purchased"]=="Jeans"
#is_cate=shopping_trends["Category"]=="Clothing"

#shopping_trends[is_item & is_cate]


shopping_trends[
    (shopping_trends["Item Purchased"]=="Jeans")&
(shopping_trends["Category"]=="Clothing")]
# Out:
#       Customer ID  Age  Gender Item Purchased  Category  \
# 2               3   50    Male          Jeans  Clothing
# 37             38   35    Male          Jeans  Clothing
# 98             99   20    Male          Jeans  Clothing
# 227           228   50    Male          Jeans  Clothing
# 259           260   32    Male          Jeans  Clothing
# ...           ...  ...     ...            ...       ...
# 3736         3737   42  Female          Jeans  Clothing
# 3779         3780   60  Female          Jeans  Clothing
# 3785         3786   64  Female          Jeans  Clothing
# 3840         3841   30  Female          Jeans  Clothing
# 3841         3842   68  Female          Jeans  Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 2                        73  Massachusetts    S     Maroon  Spring
# 37                       45        Indiana    S       Cyan  Summer
# 98                       67       New York   XL       Teal  Spring
# ...

# %%
is_cash_debit=shopping_trends["Payment Method"].isin(["Cash","Debit Card"])
shopping_trends[is_cash_debit]
# Out:
#       Customer ID  Age  Gender Item Purchased  Category  \
# 2               3   50    Male          Jeans  Clothing
# 4               5   45    Male         Blouse  Clothing
# 6               7   63    Male          Shirt  Clothing
# 7               8   27    Male         Shorts  Clothing
# 13             14   65    Male          Dress  Clothing
# ...           ...  ...     ...            ...       ...
# 3884         3885   47  Female        Sandals  Footwear
# 3889         3890   57  Female          Dress  Clothing
# 3891         3892   36  Female          Dress  Clothing
# 3894         3895   66  Female          Skirt  Clothing
# 3895         3896   40  Female         Hoodie  Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 2                        73  Massachusetts    S     Maroon  Spring
# 4                        49         Oregon    M  Turquoise  Spring
# 6                        85        Montana    M       Gray    Fall
# ...

# %% [markdown]
# # New columns

# %%
shopping_trends.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
purchase_amount_50=shopping_trends[shopping_trends["Purchase Amount (USD)"] > 50]
high_purchase_amount_50=purchase_amount_50.sort_values("Review Rating",).head()
high_purchase_amount_50
# Out:
#       Customer ID  Age Gender Item Purchased     Category  \
# 1889         1890   59   Male          Skirt     Clothing
# 1212         1213   32   Male          Shoes     Footwear
# 2544         2545   46   Male          Pants     Clothing
# 1068         1069   55   Male          Shirt     Clothing
# 281           282   38   Male           Belt  Accessories
#
#       Purchase Amount (USD)        Location Size     Color  Season  \
# 1889                     57  North Carolina    L     Peach  Spring
# 1212                     74    Pennsylvania    M    Yellow  Summer
# 2544                     70        Delaware    M       Red  Spring
# 1068                     94         Wyoming    M     Olive    Fall
# 281                      61        Oklahoma   XL  Charcoal  Spring
#
#       Review Rating Subscription Status Payment Method  Shipping Type  \
# 1889            2.5                  No     Debit Card   Next Day Air
# ...

# %%
shopping_trends["Product"] = shopping_trends["Category"] + " " + shopping_trends["Item Purchased"]
shopping_trends
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# # Aggregating Data

# %%
shopping_trends.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
# STATISTICS
print(f"Media: {shopping_trends['Purchase Amount (USD)'].mean():.2f}")
print(f"Max: {shopping_trends['Purchase Amount (USD)'].max()}")

# Other statistics like
# .median() || .mode() || .min() || .max() ||
#      .var() || .std() || .sum() || .quantile()

def pct40(column):
    return column.quantile(0.4)

def pct30(column):
    return column.quantile(0.3)


print("---")
print(f" 0.3 quantile: {shopping_trends['Purchase Amount (USD)'].agg(pct30)}")
print("---")
print(f"0.4 quantile: {shopping_trends['Purchase Amount (USD)'].agg(pct40)}")

# The .agg() method
# Out:
# Media: 59.76
# Max: 100
# ---
#  0.3 quantile: 43.0
# ---
# 0.4 quantile: 51.0

# %%
# print(shopping_trends["'Purchase Amount (USD)'"].cumsum())   # sum
# print(shopping_trends["'Purchase Amount (USD)'"].cummax())   # max 
# print(shopping_trends["'Purchase Amount (USD)'"].cummin())   # min 
# print(shopping_trends["'Purchase Amount (USD)'"].cumprod())  # product

# %%
# Import NumPy 
import numpy as np

def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)
    
print(shopping_trends['Purchase Amount (USD)'].agg(iqr))
print("----")
print(shopping_trends[['Purchase Amount (USD)','Previous Purchases']].agg(iqr))
# Out:
# 42.0
# ----
# Purchase Amount (USD)    42.0
# Previous Purchases       25.0
# dtype: float64

# %%
print(shopping_trends[['Purchase Amount (USD)','Previous Purchases']].agg([iqr,np.median]))
# Out:
#         Purchase Amount (USD)  Previous Purchases
# iqr                      42.0                25.0
# median                   60.0                25.0

# %% [markdown]
# # Counting

# %%
shopping_trends.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
shopping_trends.shape
# Out:
# (3900, 20)

# %%
shopping_trends_2=shopping_trends
shopping_trends_2.head(15)
# Out:
#     Customer ID  Age Gender Item Purchased     Category  \
# 0             1   55   Male         Blouse     Clothing
# 1             2   19   Male        Sweater     Clothing
# 2             3   50   Male          Jeans     Clothing
# 3             4   21   Male        Sandals     Footwear
# 4             5   45   Male         Blouse     Clothing
# 5             6   46   Male       Sneakers     Footwear
# 6             7   63   Male          Shirt     Clothing
# 7             8   27   Male         Shorts     Clothing
# 8             9   26   Male           Coat    Outerwear
# 9            10   57   Male        Handbag  Accessories
# 10           11   53   Male          Shoes     Footwear
# 11           12   30   Male         Shorts     Clothing
# 12           13   61   Male           Coat    Outerwear
# 13           14   65   Male          Dress     Clothing
# 14           15   64   Male           Coat    Outerwear
#
# ...

# %%
# Remove duplicates
shopping_trends_2.drop_duplicates(subset='Location')
# Out:
#      Customer ID  Age Gender Item Purchased     Category  \
# 0              1   55   Male         Blouse     Clothing
# 1              2   19   Male        Sweater     Clothing
# 2              3   50   Male          Jeans     Clothing
# 3              4   21   Male        Sandals     Footwear
# 4              5   45   Male         Blouse     Clothing
# 5              6   46   Male       Sneakers     Footwear
# 6              7   63   Male          Shirt     Clothing
# 7              8   27   Male         Shorts     Clothing
# 8              9   26   Male           Coat    Outerwear
# 9             10   57   Male        Handbag  Accessories
# 10            11   53   Male          Shoes     Footwear
# 11            12   30   Male         Shorts     Clothing
# 12            13   61   Male           Coat    Outerwear
# 13            14   65   Male          Dress     Clothing
# 14            15   64   Male           Coat    Outerwear
# ...

# %%
unique_shopping_trends_2=shopping_trends_2.drop_duplicates(subset=['Item Purchased','Category'])
print(unique_shopping_trends_2.shape)
# Out:
# (25, 20)

# %%
# Count the quantity of each type
unique_shopping_trends_2['Location'].value_counts()
# Out:
# Rhode Island     3
# Kentucky         2
# Alabama          2
# Louisiana        2
# Mississippi      1
# Tennessee        1
# Alaska           1
# North Dakota     1
# Nevada           1
# Texas            1
# Florida          1
# New Hampshire    1
# Maine            1
# Arkansas         1
# Missouri         1
# West Virginia    1
# Montana          1
# Wyoming          1
# Massachusetts    1
# Indiana          1
# Name: Location, dtype: int64

# %%
# Sort by quantity of each type
unique_shopping_trends_2['Location'].value_counts(sort=True)
# Out:
# Rhode Island     3
# Kentucky         2
# Alabama          2
# Louisiana        2
# Mississippi      1
# Tennessee        1
# Alaska           1
# North Dakota     1
# Nevada           1
# Texas            1
# Florida          1
# New Hampshire    1
# Maine            1
# Arkansas         1
# Missouri         1
# West Virginia    1
# Montana          1
# Wyoming          1
# Massachusetts    1
# Indiana          1
# Name: Location, dtype: int64

# %%
# the counts in proportions of the total
unique_shopping_trends_2['Location'].value_counts(normalize=True)
# Out:
# Rhode Island     0.12
# Kentucky         0.08
# Alabama          0.08
# Louisiana        0.08
# Mississippi      0.04
# Tennessee        0.04
# Alaska           0.04
# North Dakota     0.04
# Nevada           0.04
# Texas            0.04
# Florida          0.04
# New Hampshire    0.04
# Maine            0.04
# Arkansas         0.04
# Missouri         0.04
# West Virginia    0.04
# Montana          0.04
# Wyoming          0.04
# Massachusetts    0.04
# Indiana          0.04
# Name: Location, dtype: float64
